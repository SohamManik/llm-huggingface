# %%
from datasets import load_dataset

# %%
url = "https://github.com/crux82/squad-it/raw/master/"


data_files = {
    "train": url + 'SQuAD_it-train.json.gz',
    "test": url + 'SQuAD_it-test.json.gz'
}

squad_it_dataset = load_dataset("json", data_files = data_files , field = 'data')

# %%
squad_it_dataset["train"]['title'][0]
# Out:
# 'Terremoto del Sichuan del 2008'

# %%
squad_shuffled = squad_it_dataset.shuffle()

# %%
squad_shuffled["train"]["title"]
# Out:
# Column(['Nazionale di calcio del Canada', 'Montevideo', 'Comics', 'Alsazia', 'Wrestling professionale', ...])

# %%
squad_shuffled = squad_shuffled.flatten

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })
